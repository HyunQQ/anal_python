# %%
# Example of estimating coefficients

# Make a prediction
def predict(row, coefficients):
	yhat = coefficients[0]
	for i in range(len(row)-1):
		yhat += coefficients[i + 1] * row[i]
	return yhat

# Estimate linear regression coefficients using stochastic gradient descent
def coefficients_sgd(train, l_rate, n_epoch):
	coef = [0.0 for i in range(len(train[0]))]
	for epoch in range(n_epoch):
		sum_error = 0
		for row in train:
			yhat = predict(row, coef)
			error = yhat - row[-1]
			sum_error += error**2
			coef[0] = coef[0] - l_rate * error
			for i in range(len(row)-1):
				coef[i + 1] = coef[i + 1] - l_rate * error * row[i]
		print('>epoch=%d, lrate=%.3f, error=%.3f' % (epoch, l_rate, sum_error))
	return coef

# Calculate coefficients
dataset = [[1, 1], [2, 3], [4, 3], [3, 2], [5, 5]]
l_rate = 0.001
n_epoch = 500
coef = coefficients_sgd(dataset, l_rate, n_epoch)
print(coef)
# Out:
# >epoch=0, lrate=0.001, error=46.236
# >epoch=1, lrate=0.001, error=41.305
# >epoch=2, lrate=0.001, error=36.930
# >epoch=3, lrate=0.001, error=33.047
# >epoch=4, lrate=0.001, error=29.601
# >epoch=5, lrate=0.001, error=26.543
# >epoch=6, lrate=0.001, error=23.830
# >epoch=7, lrate=0.001, error=21.422
# >epoch=8, lrate=0.001, error=19.285
# >epoch=9, lrate=0.001, error=17.389
# >epoch=10, lrate=0.001, error=15.706
# >epoch=11, lrate=0.001, error=14.213
# >epoch=12, lrate=0.001, error=12.888
# >epoch=13, lrate=0.001, error=11.712
# >epoch=14, lrate=0.001, error=10.668
# >epoch=15, lrate=0.001, error=9.742
# >epoch=16, lrate=0.001, error=8.921
# >epoch=17, lrate=0.001, error=8.191
# >epoch=18, lrate=0.001, error=7.544
# >epoch=19, lrate=0.001, error=6.970
# >epoch=20, lrate=0.001, error=6.461
# >epoch=21, lrate=0.001, error=6.009
# >epoch=22, lrate=0.001, error=5.607
# >epoch=23, lrate=0.001, error=5.251
# >epoch=24, lrate=0.001, error=4.935
# >epoch=25, lrate=0.001, error=4.655
# >epoch=26, lrate=0.001, error=4.406
# >epoch=27, lrate=0.001, error=4.186
# >epoch=28, lrate=0.001, error=3.990
# >epoch=29, lrate=0.001, error=3.816
# >epoch=30, lrate=0.001, error=3.662
# >epoch=31, lrate=0.001, error=3.525
# >epoch=32, lrate=0.001, error=3.404
# >epoch=33, lrate=0.001, error=3.296
# >epoch=34, lrate=0.001, error=3.200
# >epoch=35, lrate=0.001, error=3.115
# >epoch=36, lrate=0.001, error=3.040
# >epoch=37, lrate=0.001, error=2.973
# >epoch=38, lrate=0.001, error=2.914
# >epoch=39, lrate=0.001, error=2.862
# >epoch=40, lrate=0.001, error=2.815
# >epoch=41, lrate=0.001, error=2.773
# >epoch=42, lrate=0.001, error=2.737
# >epoch=43, lrate=0.001, error=2.704
# >epoch=44, lrate=0.001, error=2.675
# >epoch=45, lrate=0.001, error=2.650
# >epoch=46, lrate=0.001, error=2.627
# >epoch=47, lrate=0.001, error=2.607
# >epoch=48, lrate=0.001, error=2.589
# >epoch=49, lrate=0.001, error=2.573
# >epoch=50, lrate=0.001, error=2.559
# >epoch=51, lrate=0.001, error=2.546
# >epoch=52, lrate=0.001, error=2.535
# >epoch=53, lrate=0.001, error=2.525
# >epoch=54, lrate=0.001, error=2.517
# >epoch=55, lrate=0.001, error=2.509
# >epoch=56, lrate=0.001, error=2.502
# >epoch=57, lrate=0.001, error=2.496
# >epoch=58, lrate=0.001, error=2.490
# >epoch=59, lrate=0.001, error=2.486
# >epoch=60, lrate=0.001, error=2.481
# >epoch=61, lrate=0.001, error=2.477
# >epoch=62, lrate=0.001, error=2.474
# >epoch=63, lrate=0.001, error=2.471
# >epoch=64, lrate=0.001, error=2.469
# >epoch=65, lrate=0.001, error=2.466
# >epoch=66, lrate=0.001, error=2.464
# >epoch=67, lrate=0.001, error=2.462
# >epoch=68, lrate=0.001, error=2.461
# >epoch=69, lrate=0.001, error=2.459
# >epoch=70, lrate=0.001, error=2.458
# >epoch=71, lrate=0.001, error=2.457
# >epoch=72, lrate=0.001, error=2.456
# >epoch=73, lrate=0.001, error=2.455
# >epoch=74, lrate=0.001, error=2.454
# >epoch=75, lrate=0.001, error=2.453
# >epoch=76, lrate=0.001, error=2.453
# >epoch=77, lrate=0.001, error=2.452
# >epoch=78, lrate=0.001, error=2.451
# >epoch=79, lrate=0.001, error=2.451
# >epoch=80, lrate=0.001, error=2.451
# >epoch=81, lrate=0.001, error=2.450
# >epoch=82, lrate=0.001, error=2.450
# >epoch=83, lrate=0.001, error=2.450
# >epoch=84, lrate=0.001, error=2.449
# >epoch=85, lrate=0.001, error=2.449
# >epoch=86, lrate=0.001, error=2.449
# >epoch=87, lrate=0.001, error=2.449
# >epoch=88, lrate=0.001, error=2.448
# >epoch=89, lrate=0.001, error=2.448
# >epoch=90, lrate=0.001, error=2.448
# >epoch=91, lrate=0.001, error=2.448
# >epoch=92, lrate=0.001, error=2.448
# >epoch=93, lrate=0.001, error=2.448
# >epoch=94, lrate=0.001, error=2.448
# >epoch=95, lrate=0.001, error=2.448
# >epoch=96, lrate=0.001, error=2.448
# >epoch=97, lrate=0.001, error=2.447
# >epoch=98, lrate=0.001, error=2.447
# >epoch=99, lrate=0.001, error=2.447
# >epoch=100, lrate=0.001, error=2.447
# >epoch=101, lrate=0.001, error=2.447
# >epoch=102, lrate=0.001, error=2.447
# >epoch=103, lrate=0.001, error=2.447
# >epoch=104, lrate=0.001, error=2.447
# >epoch=105, lrate=0.001, error=2.447
# >epoch=106, lrate=0.001, error=2.447
# >epoch=107, lrate=0.001, error=2.447
# >epoch=108, lrate=0.001, error=2.447
# >epoch=109, lrate=0.001, error=2.447
# >epoch=110, lrate=0.001, error=2.447
# >epoch=111, lrate=0.001, error=2.447
# >epoch=112, lrate=0.001, error=2.447
# >epoch=113, lrate=0.001, error=2.447
# >epoch=114, lrate=0.001, error=2.447
# >epoch=115, lrate=0.001, error=2.447
# >epoch=116, lrate=0.001, error=2.447
# >epoch=117, lrate=0.001, error=2.447
# >epoch=118, lrate=0.001, error=2.446
# >epoch=119, lrate=0.001, error=2.446
# >epoch=120, lrate=0.001, error=2.446
# >epoch=121, lrate=0.001, error=2.446
# >epoch=122, lrate=0.001, error=2.446
# >epoch=123, lrate=0.001, error=2.446
# >epoch=124, lrate=0.001, error=2.446
# >epoch=125, lrate=0.001, error=2.446
# >epoch=126, lrate=0.001, error=2.446
# >epoch=127, lrate=0.001, error=2.446
# >epoch=128, lrate=0.001, error=2.446
# >epoch=129, lrate=0.001, error=2.446
# >epoch=130, lrate=0.001, error=2.446
# >epoch=131, lrate=0.001, error=2.446
# >epoch=132, lrate=0.001, error=2.446
# >epoch=133, lrate=0.001, error=2.446
# >epoch=134, lrate=0.001, error=2.446
# >epoch=135, lrate=0.001, error=2.446
# >epoch=136, lrate=0.001, error=2.446
# >epoch=137, lrate=0.001, error=2.446
# >epoch=138, lrate=0.001, error=2.446
# >epoch=139, lrate=0.001, error=2.446
# >epoch=140, lrate=0.001, error=2.446
# >epoch=141, lrate=0.001, error=2.446
# >epoch=142, lrate=0.001, error=2.446
# >epoch=143, lrate=0.001, error=2.446
# >epoch=144, lrate=0.001, error=2.446
# >epoch=145, lrate=0.001, error=2.446
# >epoch=146, lrate=0.001, error=2.446
# >epoch=147, lrate=0.001, error=2.446
# >epoch=148, lrate=0.001, error=2.446
# >epoch=149, lrate=0.001, error=2.446
# >epoch=150, lrate=0.001, error=2.445
# >epoch=151, lrate=0.001, error=2.445
# >epoch=152, lrate=0.001, error=2.445
# >epoch=153, lrate=0.001, error=2.445
# >epoch=154, lrate=0.001, error=2.445
# >epoch=155, lrate=0.001, error=2.445
# >epoch=156, lrate=0.001, error=2.445
# >epoch=157, lrate=0.001, error=2.445
# >epoch=158, lrate=0.001, error=2.445
# >epoch=159, lrate=0.001, error=2.445
# >epoch=160, lrate=0.001, error=2.445
# >epoch=161, lrate=0.001, error=2.445
# >epoch=162, lrate=0.001, error=2.445
# >epoch=163, lrate=0.001, error=2.445
# >epoch=164, lrate=0.001, error=2.445
# >epoch=165, lrate=0.001, error=2.445
# >epoch=166, lrate=0.001, error=2.445
# >epoch=167, lrate=0.001, error=2.445
# >epoch=168, lrate=0.001, error=2.445
# >epoch=169, lrate=0.001, error=2.445
# >epoch=170, lrate=0.001, error=2.445
# >epoch=171, lrate=0.001, error=2.445
# >epoch=172, lrate=0.001, error=2.445
# >epoch=173, lrate=0.001, error=2.445
# >epoch=174, lrate=0.001, error=2.445
# >epoch=175, lrate=0.001, error=2.445
# >epoch=176, lrate=0.001, error=2.445
# >epoch=177, lrate=0.001, error=2.445
# >epoch=178, lrate=0.001, error=2.445
# >epoch=179, lrate=0.001, error=2.445
# >epoch=180, lrate=0.001, error=2.445
# >epoch=181, lrate=0.001, error=2.445
# >epoch=182, lrate=0.001, error=2.445
# >epoch=183, lrate=0.001, error=2.444
# >epoch=184, lrate=0.001, error=2.444
# >epoch=185, lrate=0.001, error=2.444
# >epoch=186, lrate=0.001, error=2.444
# >epoch=187, lrate=0.001, error=2.444
# >epoch=188, lrate=0.001, error=2.444
# >epoch=189, lrate=0.001, error=2.444
# >epoch=190, lrate=0.001, error=2.444
# >epoch=191, lrate=0.001, error=2.444
# >epoch=192, lrate=0.001, error=2.444
# >epoch=193, lrate=0.001, error=2.444
# >epoch=194, lrate=0.001, error=2.444
# >epoch=195, lrate=0.001, error=2.444
# >epoch=196, lrate=0.001, error=2.444
# >epoch=197, lrate=0.001, error=2.444
# >epoch=198, lrate=0.001, error=2.444
# >epoch=199, lrate=0.001, error=2.444
# >epoch=200, lrate=0.001, error=2.444
# >epoch=201, lrate=0.001, error=2.444
# >epoch=202, lrate=0.001, error=2.444
# >epoch=203, lrate=0.001, error=2.444
# >epoch=204, lrate=0.001, error=2.444
# >epoch=205, lrate=0.001, error=2.444
# >epoch=206, lrate=0.001, error=2.444
# >epoch=207, lrate=0.001, error=2.444
# >epoch=208, lrate=0.001, error=2.444
# >epoch=209, lrate=0.001, error=2.444
# >epoch=210, lrate=0.001, error=2.444
# >epoch=211, lrate=0.001, error=2.444
# >epoch=212, lrate=0.001, error=2.444
# >epoch=213, lrate=0.001, error=2.444
# >epoch=214, lrate=0.001, error=2.444
# >epoch=215, lrate=0.001, error=2.444
# >epoch=216, lrate=0.001, error=2.444
# >epoch=217, lrate=0.001, error=2.444
# >epoch=218, lrate=0.001, error=2.444
# >epoch=219, lrate=0.001, error=2.443
# >epoch=220, lrate=0.001, error=2.443
# >epoch=221, lrate=0.001, error=2.443
# >epoch=222, lrate=0.001, error=2.443
# >epoch=223, lrate=0.001, error=2.443
# >epoch=224, lrate=0.001, error=2.443
# >epoch=225, lrate=0.001, error=2.443
# >epoch=226, lrate=0.001, error=2.443
# >epoch=227, lrate=0.001, error=2.443
# >epoch=228, lrate=0.001, error=2.443
# >epoch=229, lrate=0.001, error=2.443
# >epoch=230, lrate=0.001, error=2.443
# >epoch=231, lrate=0.001, error=2.443
# >epoch=232, lrate=0.001, error=2.443
# >epoch=233, lrate=0.001, error=2.443
# >epoch=234, lrate=0.001, error=2.443
# >epoch=235, lrate=0.001, error=2.443
# >epoch=236, lrate=0.001, error=2.443
# >epoch=237, lrate=0.001, error=2.443
# >epoch=238, lrate=0.001, error=2.443
# >epoch=239, lrate=0.001, error=2.443
# >epoch=240, lrate=0.001, error=2.443
# >epoch=241, lrate=0.001, error=2.443
# >epoch=242, lrate=0.001, error=2.443
# >epoch=243, lrate=0.001, error=2.443
# >epoch=244, lrate=0.001, error=2.443
# >epoch=245, lrate=0.001, error=2.443
# >epoch=246, lrate=0.001, error=2.443
# >epoch=247, lrate=0.001, error=2.443
# >epoch=248, lrate=0.001, error=2.443
# >epoch=249, lrate=0.001, error=2.443
# >epoch=250, lrate=0.001, error=2.443
# >epoch=251, lrate=0.001, error=2.443
# >epoch=252, lrate=0.001, error=2.443
# >epoch=253, lrate=0.001, error=2.443
# >epoch=254, lrate=0.001, error=2.443
# >epoch=255, lrate=0.001, error=2.443
# >epoch=256, lrate=0.001, error=2.442
# >epoch=257, lrate=0.001, error=2.442
# >epoch=258, lrate=0.001, error=2.442
# >epoch=259, lrate=0.001, error=2.442
# >epoch=260, lrate=0.001, error=2.442
# >epoch=261, lrate=0.001, error=2.442
# >epoch=262, lrate=0.001, error=2.442
# >epoch=263, lrate=0.001, error=2.442
# >epoch=264, lrate=0.001, error=2.442
# >epoch=265, lrate=0.001, error=2.442
# >epoch=266, lrate=0.001, error=2.442
# >epoch=267, lrate=0.001, error=2.442
# >epoch=268, lrate=0.001, error=2.442
# >epoch=269, lrate=0.001, error=2.442
# >epoch=270, lrate=0.001, error=2.442
# >epoch=271, lrate=0.001, error=2.442
# >epoch=272, lrate=0.001, error=2.442
# >epoch=273, lrate=0.001, error=2.442
# >epoch=274, lrate=0.001, error=2.442
# >epoch=275, lrate=0.001, error=2.442
# >epoch=276, lrate=0.001, error=2.442
# >epoch=277, lrate=0.001, error=2.442
# >epoch=278, lrate=0.001, error=2.442
# >epoch=279, lrate=0.001, error=2.442
# >epoch=280, lrate=0.001, error=2.442
# >epoch=281, lrate=0.001, error=2.442
# >epoch=282, lrate=0.001, error=2.442
# >epoch=283, lrate=0.001, error=2.442
# >epoch=284, lrate=0.001, error=2.442
# >epoch=285, lrate=0.001, error=2.442
# >epoch=286, lrate=0.001, error=2.442
# >epoch=287, lrate=0.001, error=2.442
# >epoch=288, lrate=0.001, error=2.442
# >epoch=289, lrate=0.001, error=2.442
# >epoch=290, lrate=0.001, error=2.442
# >epoch=291, lrate=0.001, error=2.442
# >epoch=292, lrate=0.001, error=2.442
# >epoch=293, lrate=0.001, error=2.442
# >epoch=294, lrate=0.001, error=2.442
# >epoch=295, lrate=0.001, error=2.442
# >epoch=296, lrate=0.001, error=2.441
# >epoch=297, lrate=0.001, error=2.441
# >epoch=298, lrate=0.001, error=2.441
# >epoch=299, lrate=0.001, error=2.441
# >epoch=300, lrate=0.001, error=2.441
# >epoch=301, lrate=0.001, error=2.441
# >epoch=302, lrate=0.001, error=2.441
# >epoch=303, lrate=0.001, error=2.441
# >epoch=304, lrate=0.001, error=2.441
# >epoch=305, lrate=0.001, error=2.441
# >epoch=306, lrate=0.001, error=2.441
# >epoch=307, lrate=0.001, error=2.441
# >epoch=308, lrate=0.001, error=2.441
# >epoch=309, lrate=0.001, error=2.441
# >epoch=310, lrate=0.001, error=2.441
# >epoch=311, lrate=0.001, error=2.441
# >epoch=312, lrate=0.001, error=2.441
# >epoch=313, lrate=0.001, error=2.441
# >epoch=314, lrate=0.001, error=2.441
# >epoch=315, lrate=0.001, error=2.441
# >epoch=316, lrate=0.001, error=2.441
# >epoch=317, lrate=0.001, error=2.441
# >epoch=318, lrate=0.001, error=2.441
# >epoch=319, lrate=0.001, error=2.441
# >epoch=320, lrate=0.001, error=2.441
# >epoch=321, lrate=0.001, error=2.441
# >epoch=322, lrate=0.001, error=2.441
# >epoch=323, lrate=0.001, error=2.441
# >epoch=324, lrate=0.001, error=2.441
# >epoch=325, lrate=0.001, error=2.441
# >epoch=326, lrate=0.001, error=2.441
# >epoch=327, lrate=0.001, error=2.441
# >epoch=328, lrate=0.001, error=2.441
# >epoch=329, lrate=0.001, error=2.441
# >epoch=330, lrate=0.001, error=2.441
# >epoch=331, lrate=0.001, error=2.441
# >epoch=332, lrate=0.001, error=2.441
# >epoch=333, lrate=0.001, error=2.441
# >epoch=334, lrate=0.001, error=2.441
# >epoch=335, lrate=0.001, error=2.441
# >epoch=336, lrate=0.001, error=2.441
# >epoch=337, lrate=0.001, error=2.441
# >epoch=338, lrate=0.001, error=2.441
# >epoch=339, lrate=0.001, error=2.440
# >epoch=340, lrate=0.001, error=2.440
# >epoch=341, lrate=0.001, error=2.440
# >epoch=342, lrate=0.001, error=2.440
# >epoch=343, lrate=0.001, error=2.440
# >epoch=344, lrate=0.001, error=2.440
# >epoch=345, lrate=0.001, error=2.440
# >epoch=346, lrate=0.001, error=2.440
# >epoch=347, lrate=0.001, error=2.440
# >epoch=348, lrate=0.001, error=2.440
# >epoch=349, lrate=0.001, error=2.440
# >epoch=350, lrate=0.001, error=2.440
# >epoch=351, lrate=0.001, error=2.440
# >epoch=352, lrate=0.001, error=2.440
# >epoch=353, lrate=0.001, error=2.440
# >epoch=354, lrate=0.001, error=2.440
# >epoch=355, lrate=0.001, error=2.440
# >epoch=356, lrate=0.001, error=2.440
# >epoch=357, lrate=0.001, error=2.440
# >epoch=358, lrate=0.001, error=2.440
# >epoch=359, lrate=0.001, error=2.440
# >epoch=360, lrate=0.001, error=2.440
# >epoch=361, lrate=0.001, error=2.440
# >epoch=362, lrate=0.001, error=2.440
# >epoch=363, lrate=0.001, error=2.440
# >epoch=364, lrate=0.001, error=2.440
# >epoch=365, lrate=0.001, error=2.440
# >epoch=366, lrate=0.001, error=2.440
# >epoch=367, lrate=0.001, error=2.440
# >epoch=368, lrate=0.001, error=2.440
# >epoch=369, lrate=0.001, error=2.440
# >epoch=370, lrate=0.001, error=2.440
# >epoch=371, lrate=0.001, error=2.440
# >epoch=372, lrate=0.001, error=2.440
# >epoch=373, lrate=0.001, error=2.440
# >epoch=374, lrate=0.001, error=2.440
# >epoch=375, lrate=0.001, error=2.440
# >epoch=376, lrate=0.001, error=2.440
# >epoch=377, lrate=0.001, error=2.440
# >epoch=378, lrate=0.001, error=2.440
# >epoch=379, lrate=0.001, error=2.440
# >epoch=380, lrate=0.001, error=2.440
# >epoch=381, lrate=0.001, error=2.440
# >epoch=382, lrate=0.001, error=2.440
# >epoch=383, lrate=0.001, error=2.440
# >epoch=384, lrate=0.001, error=2.440
# >epoch=385, lrate=0.001, error=2.440
# >epoch=386, lrate=0.001, error=2.439
# >epoch=387, lrate=0.001, error=2.439
# >epoch=388, lrate=0.001, error=2.439
# >epoch=389, lrate=0.001, error=2.439
# >epoch=390, lrate=0.001, error=2.439
# >epoch=391, lrate=0.001, error=2.439
# >epoch=392, lrate=0.001, error=2.439
# >epoch=393, lrate=0.001, error=2.439
# >epoch=394, lrate=0.001, error=2.439
# >epoch=395, lrate=0.001, error=2.439
# >epoch=396, lrate=0.001, error=2.439
# >epoch=397, lrate=0.001, error=2.439
# >epoch=398, lrate=0.001, error=2.439
# >epoch=399, lrate=0.001, error=2.439
# >epoch=400, lrate=0.001, error=2.439
# >epoch=401, lrate=0.001, error=2.439
# >epoch=402, lrate=0.001, error=2.439
# >epoch=403, lrate=0.001, error=2.439
# >epoch=404, lrate=0.001, error=2.439
# >epoch=405, lrate=0.001, error=2.439
# >epoch=406, lrate=0.001, error=2.439
# >epoch=407, lrate=0.001, error=2.439
# >epoch=408, lrate=0.001, error=2.439
# >epoch=409, lrate=0.001, error=2.439
# >epoch=410, lrate=0.001, error=2.439
# >epoch=411, lrate=0.001, error=2.439
# >epoch=412, lrate=0.001, error=2.439
# >epoch=413, lrate=0.001, error=2.439
# >epoch=414, lrate=0.001, error=2.439
# >epoch=415, lrate=0.001, error=2.439
# >epoch=416, lrate=0.001, error=2.439
# >epoch=417, lrate=0.001, error=2.439
# >epoch=418, lrate=0.001, error=2.439
# >epoch=419, lrate=0.001, error=2.439
# >epoch=420, lrate=0.001, error=2.439
# >epoch=421, lrate=0.001, error=2.439
# >epoch=422, lrate=0.001, error=2.439
# >epoch=423, lrate=0.001, error=2.439
# >epoch=424, lrate=0.001, error=2.439
# >epoch=425, lrate=0.001, error=2.439
# >epoch=426, lrate=0.001, error=2.439
# >epoch=427, lrate=0.001, error=2.439
# >epoch=428, lrate=0.001, error=2.439
# >epoch=429, lrate=0.001, error=2.439
# >epoch=430, lrate=0.001, error=2.439
# >epoch=431, lrate=0.001, error=2.439
# >epoch=432, lrate=0.001, error=2.439
# >epoch=433, lrate=0.001, error=2.439
# >epoch=434, lrate=0.001, error=2.439
# >epoch=435, lrate=0.001, error=2.439
# >epoch=436, lrate=0.001, error=2.438
# >epoch=437, lrate=0.001, error=2.438
# >epoch=438, lrate=0.001, error=2.438
# >epoch=439, lrate=0.001, error=2.438
# >epoch=440, lrate=0.001, error=2.438
# >epoch=441, lrate=0.001, error=2.438
# >epoch=442, lrate=0.001, error=2.438
# >epoch=443, lrate=0.001, error=2.438
# >epoch=444, lrate=0.001, error=2.438
# >epoch=445, lrate=0.001, error=2.438
# >epoch=446, lrate=0.001, error=2.438
# >epoch=447, lrate=0.001, error=2.438
# >epoch=448, lrate=0.001, error=2.438
# >epoch=449, lrate=0.001, error=2.438
# >epoch=450, lrate=0.001, error=2.438
# >epoch=451, lrate=0.001, error=2.438
# >epoch=452, lrate=0.001, error=2.438
# >epoch=453, lrate=0.001, error=2.438
# >epoch=454, lrate=0.001, error=2.438
# >epoch=455, lrate=0.001, error=2.438
# >epoch=456, lrate=0.001, error=2.438
# >epoch=457, lrate=0.001, error=2.438
# >epoch=458, lrate=0.001, error=2.438
# >epoch=459, lrate=0.001, error=2.438
# >epoch=460, lrate=0.001, error=2.438
# >epoch=461, lrate=0.001, error=2.438
# >epoch=462, lrate=0.001, error=2.438
# >epoch=463, lrate=0.001, error=2.438
# >epoch=464, lrate=0.001, error=2.438
# >epoch=465, lrate=0.001, error=2.438
# >epoch=466, lrate=0.001, error=2.438
# >epoch=467, lrate=0.001, error=2.438
# >epoch=468, lrate=0.001, error=2.438
# >epoch=469, lrate=0.001, error=2.438
# >epoch=470, lrate=0.001, error=2.438
# >epoch=471, lrate=0.001, error=2.438
# >epoch=472, lrate=0.001, error=2.438
# >epoch=473, lrate=0.001, error=2.438
# >epoch=474, lrate=0.001, error=2.438
# >epoch=475, lrate=0.001, error=2.438
# >epoch=476, lrate=0.001, error=2.438
# >epoch=477, lrate=0.001, error=2.438
# >epoch=478, lrate=0.001, error=2.438
# >epoch=479, lrate=0.001, error=2.438
# >epoch=480, lrate=0.001, error=2.438
# >epoch=481, lrate=0.001, error=2.438
# >epoch=482, lrate=0.001, error=2.438
# >epoch=483, lrate=0.001, error=2.438
# >epoch=484, lrate=0.001, error=2.438
# >epoch=485, lrate=0.001, error=2.438
# >epoch=486, lrate=0.001, error=2.438
# >epoch=487, lrate=0.001, error=2.438
# >epoch=488, lrate=0.001, error=2.438
# >epoch=489, lrate=0.001, error=2.438
# >epoch=490, lrate=0.001, error=2.438
# >epoch=491, lrate=0.001, error=2.437
# >epoch=492, lrate=0.001, error=2.437
# >epoch=493, lrate=0.001, error=2.437
# >epoch=494, lrate=0.001, error=2.437
# >epoch=495, lrate=0.001, error=2.437
# >epoch=496, lrate=0.001, error=2.437
# >epoch=497, lrate=0.001, error=2.437
# >epoch=498, lrate=0.001, error=2.437
# >epoch=499, lrate=0.001, error=2.437
# [0.29049077336341483, 0.8310980517793051]
